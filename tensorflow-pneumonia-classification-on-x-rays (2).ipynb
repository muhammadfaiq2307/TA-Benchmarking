# %% [markdown]
# # 1. Introduction + Set-up
#
# Machine learning has a phenomenal range of applications, including in health and diagnostics. This tutorial will explain the complete pipeline from loading data to predicting results, and it will explain how to build an X-ray image classification model from scratch to predict whether an X-ray scan shows presence of pneumonia. This is especially useful during these current times as COVID-19 is known to cause pneumonia.
#
# This tutorial will explain how to utilize TPUs efficiently, load in image data, build and train a convolution neural network, finetune and regularize the model, and predict results. Data augmentation is not included in the model because X-ray scans are only taken in a specific orientation, and variations such as flips and rotations will not exist in real X-ray images. For a tutorial on image data augmentation, check out this [tutorial](https://www.kaggle.com/amyjang/tensorflow-data-augmentation-efficientnet).
#
# Run the following cell to load the necessary packages. Make sure to change the Accelerator on the right to `TPU`.

# %%
import re
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from kaggle_datasets import KaggleDatasets
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)
    
print(tf.__version__)
# Out:
# Number of replicas: 1
# 2.6.4

# %% [markdown]
# We need a Google Cloud link to our data to load the data using a TPU. While we're at it, we instantiate constant variables. It is generally better practice to use constant variables instead of hard-coding numbers.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
GCS_PATH = KaggleDatasets().get_gcs_path()
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
IMAGE_SIZE = [180, 180]
EPOCHS = 25

# %% [markdown]
# # 2. Load the data
#
# The Chest X-ray data we are using from [*Cell*](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia) divides the data into train, val, and test files. There are only 16 files in the validation folder, and we would prefer to have a less extreme division between the training and the validation set. We will append the validation files and create a new split that resembes the standard 80:20 division instead.

# %%
filenames = tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/val/*/*')))

train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

# %% [markdown]
# Run the following cell to see how many healthy/normal chest X-rays we have and how many pneumonia chest X-rays we have.

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print("Normal images count in training set: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
# Out:
# Normal images count in training set: 1067
# Pneumonia images count in training set: 3118

# %% [markdown]
# Notice that the there are way more images that are classified as pneumonia than normal. This shows that we have a imbalance in our data. We will correct for this imbalance later on in our notebook.

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

for f in train_list_ds.take(5):
    print(f.numpy())
# Out:
# b'gs://kds-c3fbb13cbcd3fc263a9fb6b34576fbd08f3cc7796623f5bdcb08cbff/chest_xray/train/NORMAL/NORMAL2-IM-0665-0001.jpeg'
# b'gs://kds-c3fbb13cbcd3fc263a9fb6b34576fbd08f3cc7796623f5bdcb08cbff/chest_xray/train/PNEUMONIA/person1036_virus_1730.jpeg'
# b'gs://kds-c3fbb13cbcd3fc263a9fb6b34576fbd08f3cc7796623f5bdcb08cbff/chest_xray/train/PNEUMONIA/person154_virus_305.jpeg'
# b'gs://kds-c3fbb13cbcd3fc263a9fb6b34576fbd08f3cc7796623f5bdcb08cbff/chest_xray/train/PNEUMONIA/person67_bacteria_328.jpeg'
# b'gs://kds-c3fbb13cbcd3fc263a9fb6b34576fbd08f3cc7796623f5bdcb08cbff/chest_xray/train/PNEUMONIA/person70_bacteria_341.jpeg'

# %% [markdown]
# Run the following cell to see how many images we have in our training dataset and how many images we have in our validation set. Verify that the ratio of images is 80:20.

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 4185
# Validating images count: 1047

# %% [markdown]
# As expected, we have two labels for our images.

# %%
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(GCS_PATH + "/chest_xray/train/*"))])
CLASS_NAMES
# Out:
# array(['NORMAL', 'PNEUMONIA'], dtype='<U9')

# %% [markdown]
# Currently our dataset is just a list of filenames. We want to map each filename to the corresponding (image, label) pair. The following methods will help us do that.
#
# As we only have two labels, we will rewrite the label so that `1` or `True` indicates pneumonia and `0` or `False` indicates normal.

# %%
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    # The second to last is the class-directory
    return parts[-2] == "PNEUMONIA"

# %% [markdown]
# The images originally have values that range from [0, 255]. CNNs work better with smaller numbers so we will scale this down.

# %%
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # resize the image to the desired size.
  return tf.image.resize(img, IMAGE_SIZE)

# %%
def process_path(file_path):
    label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# Let's visualize the shape of an (image, label) pair.

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %% [markdown]
# Load and format the test data as well.

# %%
test_list_ds = tf.data.Dataset.list_files(str(GCS_PATH + '/chest_xray/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

TEST_IMAGE_COUNT
# Out:
# 624

# %% [markdown]
# # 3. Visualize the dataset
#
# First, let's use buffered prefetching so we can yield data from disk without having I/O become blocking.

# %%
def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
    # This is a small dataset, only load it once, and keep it in memory.
    # use `.cache(filename)` to cache preprocessing work for datasets that don't
    # fit in memory.
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    # Repeat forever
    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    # `prefetch` lets the dataset fetch batches in the background while the model
    # is training.
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

# %% [markdown]
# Call the next batch iteration of the training data.

# %%
train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

image_batch, label_batch = next(iter(train_ds))

# %% [markdown]
# Define the method to show the images in the batch.

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(25):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

# %% [markdown]
# As the method takes in numpy arrays as its parameters, call the numpy function on the batches to return the tensor in numpy array form.

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_23/270533100.py in <module>
# ----> 1 show_batch(image_batch.numpy(), label_batch.numpy())
#
# /tmp/ipykernel_23/1861842208.py in show_batch(image_batch, label_batch)
#       3     for n in range(25):
#       4         ax = plt.subplot(5,5,n+1)
# ----> 5         plt.imshow(image_batch[n])
#       6         if label_batch[n]:
#       7             plt.title("PNEUMONIA")
#
# IndexError: index 16 is out of bounds for axis 0 with size 16

# %% [markdown]
# # 4. Build the CNN
#
# To make our model more modular and easier to understand, let's define some blocks. As we're building a convolution neural network, we'll create a convolution block and a dense layer block.
#
# The architecture for this CNN has been inspired by this [article](https://towardsdatascience.com/deep-learning-for-detecting-pneumonia-from-x-ray-images-fc9a3d9fdba8).

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %% [markdown]
# The following method will define the function to build our model for us. The Dropout layers are important as they "drop out," hence the name, certain nodes to reduce the likelikhood of the model overfitting. We want to end the model with a Dense layer of one node, as this will be the output that determines if an X-ray shows an image of pneumonia.

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# # 5. Correct for data imbalance
#
# We saw earlier in this notebook that the data was imbalanced, with more images classified as pneumonia than normal. We will correct for that in this following section.

# %%
initial_bias = np.log([COUNT_PNEUMONIA/COUNT_NORMAL])
initial_bias
# Out:
# array([1.0723408])

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.96
# Weight for class 1: 0.67

# %% [markdown]
# The weight for class `0` (Normal) is a lot higher than the weight for class `1` (Pneumonia). Because there are less normal images, each normal image will be weighted more to balance the data as the CNN works best when the training data is balanced.

# %% [markdown]
# # 6. Train the model
#
# Since there are only two possible labels for the image, we will be using the `binary_crossentropy` loss. When we fit the model, identify the class weights. Because we are using a TPU, training will be relatively quick.
#
# For our metrics, we want to include precision and recall as they will provide use with a more informed picture of how good our model is. Accuracy tells us what fractions are the labels are correct. Since our data is not balanced, accuracy might give a skewed sense of a good model (i.e. a model that always predicts PNEUMONIA will be 74% accurate but is not a good model).
#
# Precision is the number of true positives (TP) over the sum of TP and false positives (FP). It shows what fraction of labeled positives are actually correct.
#
# Recall is the number of TP over the sum of TP and false negatves (FN). It shows what fraction of actual positives are correct.

# %%
with strategy.scope():
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %% [markdown]
# From exploring the data and the model, I noticed that the training for the model has a slow start. However, after 25 epochs, the model slowly starts to converge.

# %%
history = model.fit(
    train_ds,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_ds,
    validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
    class_weight=class_weight,
)
# Out:
# Epoch 1/25
# 261/261 [==============================] - 433s 1s/step - loss: 0.3976 - accuracy: 0.8017 - precision: 0.9525 - recall: 0.7725 - val_loss: 0.6964 - val_accuracy: 0.7298 - val_precision: 0.7298 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.2369 - accuracy: 0.9059 - precision: 0.9699 - recall: 0.9015 - val_loss: 1.9556 - val_accuracy: 0.7288 - val_precision: 0.7288 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.2046 - accuracy: 0.9277 - precision: 0.9773 - recall: 0.9246 - val_loss: 0.0996 - val_accuracy: 0.9615 - val_precision: 0.9664 - val_recall: 0.9816
# Epoch 4/25
# 261/261 [==============================] - 15s 58ms/step - loss: 0.1723 - accuracy: 0.9313 - precision: 0.9786 - recall: 0.9279 - val_loss: 0.1864 - val_accuracy: 0.9375 - val_precision: 0.9986 - val_recall: 0.9156
# Epoch 5/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.1567 - accuracy: 0.9456 - precision: 0.9833 - recall: 0.9431 - val_loss: 0.1215 - val_accuracy: 0.9510 - val_precision: 0.9958 - val_recall: 0.9368
# Epoch 6/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.1447 - accuracy: 0.9454 - precision: 0.9852 - recall: 0.9408 - val_loss: 0.1075 - val_accuracy: 0.9615 - val_precision: 0.9918 - val_recall: 0.9551
# Epoch 7/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.1508 - accuracy: 0.9444 - precision: 0.9842 - recall: 0.9406 - val_loss: 0.2679 - val_accuracy: 0.9183 - val_precision: 1.0000 - val_recall: 0.8880
# Epoch 8/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.1300 - accuracy: 0.9519 - precision: 0.9860 - recall: 0.9489 - val_loss: 0.3796 - val_accuracy: 0.8683 - val_precision: 1.0000 - val_recall: 0.8195
# Epoch 9/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.1439 - accuracy: 0.9454 - precision: 0.9807 - recall: 0.9454 - val_loss: 0.1453 - val_accuracy: 0.9442 - val_precision: 0.9958 - val_recall: 0.9275
# Epoch 10/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.1156 - accuracy: 0.9567 - precision: 0.9883 - recall: 0.9529 - val_loss: 0.0784 - val_accuracy: 0.9712 - val_precision: 0.9893 - val_recall: 0.9711
# Epoch 11/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.1098 - accuracy: 0.9600 - precision: 0.9877 - recall: 0.9582 - val_loss: 0.0887 - val_accuracy: 0.9644 - val_precision: 0.9918 - val_recall: 0.9592
# Epoch 12/25
# 261/261 [==============================] - 15s 56ms/step - loss: 0.1243 - accuracy: 0.9521 - precision: 0.9883 - recall: 0.9469 - val_loss: 0.1195 - val_accuracy: 0.9577 - val_precision: 1.0000 - val_recall: 0.9421
# Epoch 13/25
# 261/261 [==============================] - 15s 58ms/step - loss: 0.1035 - accuracy: 0.9607 - precision: 0.9901 - recall: 0.9571 - val_loss: 0.0715 - val_accuracy: 0.9769 - val_precision: 0.9920 - val_recall: 0.9764
# Epoch 14/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.1162 - accuracy: 0.9576 - precision: 0.9877 - recall: 0.9549 - val_loss: 0.0820 - val_accuracy: 0.9712 - val_precision: 0.9932 - val_recall: 0.9671
# Epoch 15/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.1153 - accuracy: 0.9574 - precision: 0.9884 - recall: 0.9542 - val_loss: 0.1068 - val_accuracy: 0.9606 - val_precision: 0.9905 - val_recall: 0.9553
# Epoch 16/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.1020 - accuracy: 0.9617 - precision: 0.9920 - recall: 0.9562 - val_loss: 0.1973 - val_accuracy: 0.9442 - val_precision: 1.0000 - val_recall: 0.9238
# Epoch 17/25
# 261/261 [==============================] - 15s 58ms/step - loss: 0.0873 - accuracy: 0.9689 - precision: 0.9914 - recall: 0.9666 - val_loss: 0.0861 - val_accuracy: 0.9683 - val_precision: 0.9959 - val_recall: 0.9605
# Epoch 18/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.1148 - accuracy: 0.9583 - precision: 0.9893 - recall: 0.9544 - val_loss: 0.0708 - val_accuracy: 0.9769 - val_precision: 0.9973 - val_recall: 0.9711
# Epoch 19/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.0815 - accuracy: 0.9701 - precision: 0.9950 - recall: 0.9647 - val_loss: 0.1337 - val_accuracy: 0.9558 - val_precision: 1.0000 - val_recall: 0.9395
# Epoch 20/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.0921 - accuracy: 0.9732 - precision: 0.9924 - recall: 0.9713 - val_loss: 0.2393 - val_accuracy: 0.9173 - val_precision: 1.0000 - val_recall: 0.8867
# Epoch 21/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.0732 - accuracy: 0.9737 - precision: 0.9944 - recall: 0.9701 - val_loss: 0.2143 - val_accuracy: 0.9163 - val_precision: 1.0000 - val_recall: 0.8857
# Epoch 22/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.0799 - accuracy: 0.9682 - precision: 0.9934 - recall: 0.9636 - val_loss: 0.0885 - val_accuracy: 0.9663 - val_precision: 0.9986 - val_recall: 0.9553
# Epoch 23/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.0702 - accuracy: 0.9732 - precision: 0.9947 - recall: 0.9692 - val_loss: 0.0821 - val_accuracy: 0.9721 - val_precision: 0.9946 - val_recall: 0.9672
# Epoch 24/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.0578 - accuracy: 0.9804 - precision: 0.9961 - recall: 0.9775 - val_loss: 0.0599 - val_accuracy: 0.9750 - val_precision: 0.9933 - val_recall: 0.9724
# Epoch 25/25
# 261/261 [==============================] - 15s 57ms/step - loss: 0.0643 - accuracy: 0.9782 - precision: 0.9944 - recall: 0.9762 - val_loss: 0.1661 - val_accuracy: 0.9327 - val_precision: 0.9986 - val_recall: 0.9093

# %% [markdown]
# # 7. Finetune the model
#
# Finetuning is an art when it comes to Machine Learning, and there are many ways to adjust the model in efforts to improve it. Finetuning is beyond the scope of this notebook, but check out this [article](https://www.pyimagesearch.com/2019/06/03/fine-tuning-with-keras-and-deep-learning/) for more information.
#
# For our purposes, we'll use Keras callbacks to further finetune our model. The checkpoint callback saves the best weights of the model, so next time we want to use the model, we do not have to spend time training it. The early stopping callback stops the training process when the model starts becoming stagnant, or even worse, when the model starts overfitting. Since we set `restore_best_weights` to `True`, the returned model at the end of the training process will be the model with the best weights (i.e. low loss and high accuracy).

# %%
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("xray_model.h5",
                                                    save_best_only=True)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,
                                                     restore_best_weights=True)

# %% [markdown]
# We also want to finetune our learning rate. Too high of a learning rate will cause the model to diverge. Too small of a learning rate will cause the model to be too slow. We implement the exponential learning rate scheduling method below.

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 20)

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
history = model.fit(
    train_ds,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=100,
    validation_data=val_ds,
    validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
    class_weight=class_weight,
    callbacks=[checkpoint_cb, early_stopping_cb, lr_scheduler]
)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 4s 112ms/step - loss: 0.1191 - accuracy: 0.9583 - precision: 0.9877 - recall: 0.9555 - val_loss: 0.3463 - val_accuracy: 0.8457 - val_precision: 1.0000 - val_recall: 0.7937 - lr: 0.0100
# Epoch 2/100
# 32/32 [==============================] - 3s 93ms/step - loss: 0.1548 - accuracy: 0.9319 - precision: 0.9825 - recall: 0.9247 - val_loss: 0.6780 - val_accuracy: 0.8330 - val_precision: 0.9983 - val_recall: 0.7784 - lr: 0.0089
# Epoch 3/100
# 32/32 [==============================] - 3s 96ms/step - loss: 0.1709 - accuracy: 0.9355 - precision: 0.9819 - recall: 0.9301 - val_loss: 34.3623 - val_accuracy: 0.2510 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0079
# Epoch 4/100
# 32/32 [==============================] - 3s 94ms/step - loss: 0.1802 - accuracy: 0.9238 - precision: 0.9804 - recall: 0.9161 - val_loss: 10.4584 - val_accuracy: 0.3623 - val_precision: 1.0000 - val_recall: 0.1453 - lr: 0.0071
# Epoch 5/100
# 32/32 [==============================] - 3s 96ms/step - loss: 0.1535 - accuracy: 0.9382 - precision: 0.9799 - recall: 0.9354 - val_loss: 1.7526 - val_accuracy: 0.5615 - val_precision: 0.9969 - val_recall: 0.4151 - lr: 0.0063
# Epoch 6/100
# 32/32 [==============================] - 3s 92ms/step - loss: 0.1325 - accuracy: 0.9502 - precision: 0.9869 - recall: 0.9453 - val_loss: 0.5494 - val_accuracy: 0.8340 - val_precision: 1.0000 - val_recall: 0.7781 - lr: 0.0056
# Epoch 7/100
# 32/32 [==============================] - 3s 93ms/step - loss: 0.1253 - accuracy: 0.9485 - precision: 0.9869 - recall: 0.9428 - val_loss: 0.9511 - val_accuracy: 0.7090 - val_precision: 1.0000 - val_recall: 0.6099 - lr: 0.0050
# Epoch 8/100
# 32/32 [==============================] - 3s 100ms/step - loss: 0.1182 - accuracy: 0.9507 - precision: 0.9893 - recall: 0.9436 - val_loss: 0.2004 - val_accuracy: 0.9131 - val_precision: 0.9985 - val_recall: 0.8850 - lr: 0.0045
# Epoch 9/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.1016 - accuracy: 0.9626 - precision: 0.9902 - recall: 0.9593 - val_loss: 0.2811 - val_accuracy: 0.9062 - val_precision: 0.9985 - val_recall: 0.8755 - lr: 0.0040
# Epoch 10/100
# 32/32 [==============================] - 3s 90ms/step - loss: 0.1226 - accuracy: 0.9524 - precision: 0.9920 - recall: 0.9433 - val_loss: 0.2469 - val_accuracy: 0.8965 - val_precision: 0.9955 - val_recall: 0.8652 - lr: 0.0035
# Epoch 11/100
# 32/32 [==============================] - 3s 100ms/step - loss: 0.1181 - accuracy: 0.9570 - precision: 0.9854 - recall: 0.9561 - val_loss: 0.0842 - val_accuracy: 0.9717 - val_precision: 0.9908 - val_recall: 0.9715 - lr: 0.0032
# Epoch 12/100
# 32/32 [==============================] - 3s 88ms/step - loss: 0.1056 - accuracy: 0.9607 - precision: 0.9871 - recall: 0.9595 - val_loss: 0.1111 - val_accuracy: 0.9502 - val_precision: 0.9945 - val_recall: 0.9389 - lr: 0.0028
# Epoch 13/100
# 32/32 [==============================] - 3s 99ms/step - loss: 0.0874 - accuracy: 0.9656 - precision: 0.9922 - recall: 0.9610 - val_loss: 0.0700 - val_accuracy: 0.9717 - val_precision: 0.9920 - val_recall: 0.9699 - lr: 0.0025
# Epoch 14/100
# 32/32 [==============================] - 3s 98ms/step - loss: 0.0860 - accuracy: 0.9697 - precision: 0.9912 - recall: 0.9678 - val_loss: 0.0620 - val_accuracy: 0.9795 - val_precision: 0.9908 - val_recall: 0.9817 - lr: 0.0022
# Epoch 15/100
# 32/32 [==============================] - 3s 89ms/step - loss: 0.0860 - accuracy: 0.9690 - precision: 0.9912 - recall: 0.9666 - val_loss: 0.0655 - val_accuracy: 0.9795 - val_precision: 0.9894 - val_recall: 0.9829 - lr: 0.0020
# Epoch 16/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.0915 - accuracy: 0.9724 - precision: 0.9910 - recall: 0.9717 - val_loss: 0.0665 - val_accuracy: 0.9746 - val_precision: 0.9881 - val_recall: 0.9778 - lr: 0.0018
# Epoch 17/100
# 32/32 [==============================] - 3s 90ms/step - loss: 0.0689 - accuracy: 0.9766 - precision: 0.9946 - recall: 0.9737 - val_loss: 0.0665 - val_accuracy: 0.9707 - val_precision: 0.9946 - val_recall: 0.9661 - lr: 0.0016
# Epoch 18/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.0697 - accuracy: 0.9746 - precision: 0.9946 - recall: 0.9711 - val_loss: 0.0631 - val_accuracy: 0.9785 - val_precision: 0.9920 - val_recall: 0.9790 - lr: 0.0014
# Epoch 19/100
# 32/32 [==============================] - 3s 92ms/step - loss: 0.0685 - accuracy: 0.9744 - precision: 0.9953 - recall: 0.9699 - val_loss: 0.0709 - val_accuracy: 0.9727 - val_precision: 0.9946 - val_recall: 0.9685 - lr: 0.0013
# Epoch 20/100
# 32/32 [==============================] - 3s 103ms/step - loss: 0.0545 - accuracy: 0.9805 - precision: 0.9943 - recall: 0.9792 - val_loss: 0.0555 - val_accuracy: 0.9756 - val_precision: 0.9920 - val_recall: 0.9752 - lr: 0.0011
# Epoch 21/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.0678 - accuracy: 0.9739 - precision: 0.9929 - recall: 0.9717 - val_loss: 0.0593 - val_accuracy: 0.9756 - val_precision: 0.9907 - val_recall: 0.9765 - lr: 0.0010
# Epoch 22/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.0748 - accuracy: 0.9805 - precision: 0.9953 - recall: 0.9782 - val_loss: 0.0660 - val_accuracy: 0.9746 - val_precision: 0.9960 - val_recall: 0.9700 - lr: 8.9125e-04
# Epoch 23/100
# 32/32 [==============================] - 3s 102ms/step - loss: 0.0572 - accuracy: 0.9790 - precision: 0.9956 - recall: 0.9759 - val_loss: 0.0535 - val_accuracy: 0.9785 - val_precision: 0.9869 - val_recall: 0.9843 - lr: 7.9433e-04
# Epoch 24/100
# 32/32 [==============================] - 3s 101ms/step - loss: 0.0508 - accuracy: 0.9814 - precision: 0.9950 - recall: 0.9800 - val_loss: 0.0519 - val_accuracy: 0.9814 - val_precision: 0.9895 - val_recall: 0.9857 - lr: 7.0795e-04
# Epoch 25/100
# 32/32 [==============================] - 3s 92ms/step - loss: 0.0488 - accuracy: 0.9834 - precision: 0.9956 - recall: 0.9818 - val_loss: 0.0530 - val_accuracy: 0.9775 - val_precision: 0.9920 - val_recall: 0.9777 - lr: 6.3096e-04
# Epoch 26/100
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0559 - accuracy: 0.9844 - precision: 0.9963 - recall: 0.9827 - val_loss: 0.0528 - val_accuracy: 0.9775 - val_precision: 0.9907 - val_recall: 0.9791 - lr: 5.6234e-04
# Epoch 27/100
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0457 - accuracy: 0.9817 - precision: 0.9966 - recall: 0.9785 - val_loss: 0.0696 - val_accuracy: 0.9746 - val_precision: 0.9986 - val_recall: 0.9672 - lr: 5.0119e-04
# Epoch 28/100
# 32/32 [==============================] - 3s 95ms/step - loss: 0.0478 - accuracy: 0.9824 - precision: 0.9963 - recall: 0.9798 - val_loss: 0.0525 - val_accuracy: 0.9814 - val_precision: 0.9921 - val_recall: 0.9830 - lr: 4.4668e-04
# Epoch 29/100
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0530 - accuracy: 0.9819 - precision: 0.9956 - recall: 0.9799 - val_loss: 0.0523 - val_accuracy: 0.9824 - val_precision: 0.9960 - val_recall: 0.9804 - lr: 3.9811e-04
# Epoch 30/100
# 32/32 [==============================] - 3s 88ms/step - loss: 0.0537 - accuracy: 0.9819 - precision: 0.9980 - recall: 0.9776 - val_loss: 0.0854 - val_accuracy: 0.9668 - val_precision: 0.9986 - val_recall: 0.9569 - lr: 3.5481e-04
# Epoch 31/100
# 32/32 [==============================] - 3s 102ms/step - loss: 0.0459 - accuracy: 0.9829 - precision: 0.9967 - recall: 0.9804 - val_loss: 0.0500 - val_accuracy: 0.9795 - val_precision: 0.9908 - val_recall: 0.9817 - lr: 3.1623e-04
# Epoch 32/100
# 32/32 [==============================] - 3s 87ms/step - loss: 0.0491 - accuracy: 0.9836 - precision: 0.9953 - recall: 0.9824 - val_loss: 0.0613 - val_accuracy: 0.9756 - val_precision: 0.9960 - val_recall: 0.9714 - lr: 2.8184e-04
# Epoch 33/100
# 32/32 [==============================] - 3s 89ms/step - loss: 0.0404 - accuracy: 0.9858 - precision: 0.9973 - recall: 0.9836 - val_loss: 0.0552 - val_accuracy: 0.9795 - val_precision: 0.9947 - val_recall: 0.9778 - lr: 2.5119e-04
# Epoch 34/100
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0451 - accuracy: 0.9844 - precision: 0.9957 - recall: 0.9833 - val_loss: 0.0568 - val_accuracy: 0.9785 - val_precision: 0.9947 - val_recall: 0.9764 - lr: 2.2387e-04
# Epoch 35/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.0553 - accuracy: 0.9836 - precision: 0.9960 - recall: 0.9817 - val_loss: 0.0557 - val_accuracy: 0.9775 - val_precision: 0.9921 - val_recall: 0.9779 - lr: 1.9953e-04
# Epoch 36/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.0477 - accuracy: 0.9834 - precision: 0.9950 - recall: 0.9826 - val_loss: 0.0581 - val_accuracy: 0.9766 - val_precision: 0.9934 - val_recall: 0.9753 - lr: 1.7783e-04
# Epoch 37/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.0574 - accuracy: 0.9829 - precision: 0.9970 - recall: 0.9800 - val_loss: 0.0527 - val_accuracy: 0.9795 - val_precision: 0.9934 - val_recall: 0.9791 - lr: 1.5849e-04
# Epoch 38/100
# 32/32 [==============================] - 3s 92ms/step - loss: 0.0396 - accuracy: 0.9878 - precision: 0.9980 - recall: 0.9855 - val_loss: 0.0560 - val_accuracy: 0.9795 - val_precision: 0.9947 - val_recall: 0.9777 - lr: 1.4125e-04
# Epoch 39/100
# 32/32 [==============================] - 3s 90ms/step - loss: 0.0397 - accuracy: 0.9834 - precision: 0.9970 - recall: 0.9805 - val_loss: 0.0541 - val_accuracy: 0.9795 - val_precision: 0.9934 - val_recall: 0.9790 - lr: 1.2589e-04
# Epoch 40/100
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0452 - accuracy: 0.9844 - precision: 0.9970 - recall: 0.9818 - val_loss: 0.0546 - val_accuracy: 0.9805 - val_precision: 0.9947 - val_recall: 0.9791 - lr: 1.1220e-04
# Epoch 41/100
# 32/32 [==============================] - 4s 122ms/step - loss: 0.0443 - accuracy: 0.9844 - precision: 0.9970 - recall: 0.9820 - val_loss: 0.0575 - val_accuracy: 0.9785 - val_precision: 0.9947 - val_recall: 0.9764 - lr: 1.0000e-04

# %% [markdown]
# # 8. Visualizing model performance
#
# Let's plot the model accuracy and loss for the training and the validating set. These plots show the accuracy and loss values for the second round of training. Since we initially trained the model with 30 epochs, these would be epochs 31-45. Note that no random seed is specified for this notebook. For your notebook, there might be slight variance.

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# We see that the accuracy for our model is around 98%. Finetune the model further to see if we can achieve a higher accuracy.

# %% [markdown]
# # 9. Predict and evaluate results
#
# Let's evaluate the model on our test data!

# %%
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 39/39 [==============================] - 51s 1s/step - loss: 0.5564 - accuracy: 0.8558 - precision: 0.8363 - recall: 0.9564

# %% [markdown]
# We see that our accuracy on our test data is 83%, which is lower than the accuracy for our validating set. This may indicate overfitting. Try finetuning the model further to decrease overfitting to the training and validation sets.
#
# Our recall is greater than our precision, indicating that almost all pneumonia images are correctly identified but some normal images are falsely identified. We should aim to increase our precision.
